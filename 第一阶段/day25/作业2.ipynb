# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data=pd.read_csv('./drinks.csv')
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#2
data.head(6)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9       NaN

# %%
#3
data.continent.fillna(value=None,method='ffill')
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
#        ..
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 193, dtype: object

# %%
#4
data.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
db=data.groupby('continent')

# %%
#5
db.agg({
   'beer_servings':'mean'
})
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
#6
db.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
#6
db.median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
db.spirit_servings.agg(['max','min','mean'])
# Out:
#            max  min        mean
# continent
# AF         152    0   16.339623
# AS         326    0   60.840909
# EU         373    0  132.555556
# OC         254    0   58.437500
# SA         302   25  114.750000

# %%
#9
data[data.country=='China']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 36   China             79              192              8
#
#     total_litres_of_pure_alcohol continent
# 36                           5.0        AS

# %%
#10
data_sort=data.sort_values('beer_servings',ascending=False,ignore_index=True)
data_sort[data_sort.country=='China']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 90   China             79              192              8
#
#     total_litres_of_pure_alcohol continent
# 90                           5.0        AS
