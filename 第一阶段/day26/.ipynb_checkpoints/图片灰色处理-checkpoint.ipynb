# %%
import numpy as np
import pandas as pd
import scipy
from scipy.fftpack import fft2,ifft2

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
lq=plt.imread('./lq.jpeg')
plt.imshow(lq)

# %%
#将将三维设置为二维
#外层 axis=0  中间为1  内层为2

#把内层设置为一个数据
data=lq.max(axis=2)
data=lq.mean(axis=2)

# %%
plt.imshow(data,cmap="gray")
